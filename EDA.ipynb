# %%
import nfl_data_py as nfl

# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %%
pbp_data = nfl.import_pbp_data([2024], downcast=True, cache=False, alt_path=None)
# Out:
# 2024 done.
# Downcasting floats.

# %%
pbp_data
# Out:
#        play_id          game_id old_game_id_x home_team away_team season_type  \
# 0          1.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 1         40.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 2         61.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 3         83.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 4        108.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# ...        ...              ...           ...       ...       ...         ...
# 49487   4158.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49488   4181.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49489   4203.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49490   4225.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49491   4247.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
#
# ...

# %%
pbp_data.columns
# Out:
# Index(['play_id', 'game_id', 'old_game_id_x', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'was_pressure', 'route', 'defense_man_zone_type',
#        'defense_coverage_type', 'offense_names', 'defense_names',
#        'offense_positions', 'defense_positions', 'offense_numbers',
#        'defense_numbers'],
#       dtype='object', length=397)

# %%
fourth_down_data = pbp_data[pbp_data['down'] == 4]

# %%
fourth_down_conversion_data = fourth_down_data[~fourth_down_data['play_type'].isin(['punt', 'field_goal'])]

# %%
nfl.see_pbp_cols().tolist()
# Out:
# ['play_id',
#  'game_id',
#  'old_game_id',
#  'home_team',
#  'away_team',
#  'season_type',
#  'week',
#  'posteam',
#  'posteam_type',
#  'defteam',
#  'side_of_field',
#  'yardline_100',
#  'game_date',
#  'quarter_seconds_remaining',
#  'half_seconds_remaining',
#  'game_seconds_remaining',
#  'game_half',
#  'quarter_end',
#  'drive',
#  'sp',
#  'qtr',
#  'down',
#  'goal_to_go',
#  'time',
#  'yrdln',
#  'ydstogo',
#  'ydsnet',
#  'desc',
#  'play_type',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'qb_kneel',
#  'qb_spike',
#  'qb_scramble',
#  'pass_length',
#  'pass_location',
#  'air_yards',
#  'yards_after_catch',
#  'run_location',
#  'run_gap',
#  'field_goal_result',
#  'kick_distance',
#  'extra_point_result',
#  'two_point_conv_result',
#  'home_timeouts_remaining',
#  'away_timeouts_remaining',
#  'timeout',
#  'timeout_team',
#  'td_team',
#  'td_player_name',
#  'td_player_id',
#  'posteam_timeouts_remaining',
# ...

# %%
fourth_down_conversion_data
# Out:
#        play_id          game_id old_game_id_x home_team away_team season_type  \
# 103     2632.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 123     3124.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 160     4062.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 213     1265.0   2024_01_BAL_KC    2024090500        KC       BAL         REG
# 312     3584.0   2024_01_BAL_KC    2024090500        KC       BAL         REG
# ...        ...              ...           ...       ...       ...         ...
# 49389   1839.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49423   2616.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49431   2834.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49461   3510.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49484   4093.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
#
# ...

# %%
relevant_fourth_down_data = fourth_down_data.iloc[:, list(range(42)) + list(range(54,64)) + list(range(69, 70)) + list(range(125, 130))]

# %%
relevant_fourth_down_data
# Out:
#        play_id          game_id old_game_id_x home_team away_team season_type  \
# 31       823.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 43      1120.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 93      2360.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 97      2468.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 103     2632.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# ...        ...              ...           ...       ...       ...         ...
# 49431   2834.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49453   3344.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49461   3510.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49462   3547.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49484   4093.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
#
# ...

# %%
relevant_fourth_down_conversion_data = fourth_down_conversion_data.iloc[:, list(range(42)) + list(range(54,64)) + list(range(69, 70)) + list(range(125, 130))]

# %%
relevant_fourth_down_conversion_data
# Out:
#        play_id          game_id old_game_id_x home_team away_team season_type  \
# 103     2632.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 123     3124.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 160     4062.0  2024_01_ARI_BUF    2024090801       BUF       ARI         REG
# 213     1265.0   2024_01_BAL_KC    2024090500        KC       BAL         REG
# 312     3584.0   2024_01_BAL_KC    2024090500        KC       BAL         REG
# ...        ...              ...           ...       ...       ...         ...
# 49389   1839.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49423   2616.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49431   2834.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49461   3510.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 49484   4093.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
#
# ...
